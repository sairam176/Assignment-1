# %%
# Assignment:  PYTHON 1

#1. Install Jupyter notebook and run the first program and share the screenshot of the output

# I have successfully installed Jupyter notebook
# My first program would be to identify divisibles of a given number

print('Type a number of your choice and press Enter')
Number=int(input())
Divisors =[]
denominators=range(1,Number+1)
for N in denominators:
    if Number % N == 0:
        Divisors.append(N)
print(Number,'is evenly divisible by', Divisors)
# Out:
# Type a number of your choice and press Enter
# 28
# 28 is evenly divisible by [1, 2, 4, 7, 14, 28]

# %%
# Here is the screenshot of my first program

from IPython.display import Image
Image(filename='/Users/sm31/Desktop/Assignment Screenshot.png')

# %%
# 2. Write a program which will find all such numbers which are divisible by 7 but are not a multiple of 5,
# between 2000 and 3200 (both included).
# The numbers obtained should be printed in a comma-separated sequence on a single line.

# First, we'll create a list Y with a range between 2000 to 3201 (to include 3200)
# X will be the variable within the range Y
# Define the criteria i.e., numbers in the range Y that are divisible by 7 but not a multiple of 5
# Print such numbers

Y=[]
range(2000,3201)
for X in range(2000,3201):
    if (X%7==0 and X%5!=0):
        Y.append(str(X))
print(','.join(Y))
# Out:
# 2002,2009,2016,2023,2037,2044,2051,2058,2072,2079,2086,2093,2107,2114,2121,2128,2142,2149,2156,2163,2177,2184,2191,2198,2212,2219,2226,2233,2247,2254,2261,2268,2282,2289,2296,2303,2317,2324,2331,2338,2352,2359,2366,2373,2387,2394,2401,2408,2422,2429,2436,2443,2457,2464,2471,2478,2492,2499,2506,2513,2527,2534,2541,2548,2562,2569,2576,2583,2597,2604,2611,2618,2632,2639,2646,2653,2667,2674,2681,2688,2702,2709,2716,2723,2737,2744,2751,2758,2772,2779,2786,2793,2807,2814,2821,2828,2842,2849,2856,2863,2877,2884,2891,2898,2912,2919,2926,2933,2947,2954,2961,2968,2982,2989,2996,3003,3017,3024,3031,3038,3052,3059,3066,3073,3087,3094,3101,3108,3122,3129,3136,3143,3157,3164,3171,3178,3192,3199

# %%
# 3. Write a Python program to accept the user's first and last name
# and then getting them printed in the the reverse order with a space between first name and last name.

#Here is the programe that asks the user to give first name and last name and then prints them in reverse order

Firstname= input("Type your first name and press Enter - ")
Lastname = input("Type your last name and press Enter - ")
print ('Your complete name in reverse order is - ',Firstname[::-1],"",Lastname[::-1])
# Out:
# Type your first name and press Enter - Saikumar
# Type your last name and press Enter - Minikuri
# Your complete name in reverse order is -  ramukiaS  irukiniM

# %%
# 4. Write a Python program to find the volume of a sphere with diameter 12 cm. Formula: V=4/3 * π * r 3

# Here is the program that asks the user to give the diameter (D) of the Sphere 
# Program has Radius (r) & pi defined
# Prints the Volume (V)

D =(int(input('Please type the diameter of Sphere - ')))
r = D/2
pi = 3.1415926535897931
V = 4/3*pi*r**3
print('The volume of Sphere is: ',V, "cm")
# Out:
# Please type the diameter of Sphere - 15
# The volume of Sphere is:  1767.1458676442585 cm
